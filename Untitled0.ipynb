# %% [markdown]
# <a href="https://colab.research.google.com/github/ssrapidinnovation/AI-code/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python3 -m pip install --upgrade langchain deeplake openai tiktoken
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 759.0/759.0 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.9/475.9 kB 22.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 32.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import os

from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import DeepLake

os.environ['OPENAI_API_KEY'] = "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"
os.environ['ACTIVELOOP_TOKEN'] = "eyJhbGciOiJIUzUxMiIsImlhdCI6MTY4MzUxMTA3MiwiZXhwIjoxNjgzNTk3NDYyfQ.eyJpZCI6InNzIn0.NhU3dir9sTKQM8hl3Snc1JkpZThi2OZKG6B721-k6hS5N_qdoo7hLvig4gH_DTiOHj9NaNcpA0d3EU5aHE5CDw"
embeddings = OpenAIEmbeddings()

# %%
# !git version
# Out:
# git version 2.25.1

# %%
# !git config –global user.email “ss@rapidinnovation.dev”
# !git config –global user.name ssrapidinnovation
# Out:
# fatal: not in a git directory
# fatal: not in a git directory

# %%
# !git clone https://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@github.com/ssrapidinnovation/task-manager # replace any repository of your choice
# Out:
# Cloning into 'task-manager'...
# remote: Enumerating objects: 31540, done.
# remote: Counting objects: 100% (31540/31540), done.
# remote: Compressing objects: 100% (18414/18414), done.
# remote: Total 31540 (delta 11174), reused 31540 (delta 11174), pack-reused 0
# Receiving objects: 100% (31540/31540), 39.62 MiB | 16.39 MiB/s, done.
# Resolving deltas: 100% (11174/11174), done.
# Updating files: 100% (39800/39800), done.

# %%
ls
# Out:
# sample_data/  task-manager/  the-algorithm/

# %%
import os
from langchain.document_loaders import TextLoader

root_dir = './task-manager'
docs = []
for dirpath, dirnames, filenames in os.walk(root_dir):
    for file in filenames:
        try: 
            loader = TextLoader(os.path.join(dirpath, file), encoding='utf-8')
            docs.extend(loader.load_and_split())
        except Exception as e: 
            pass

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(docs)
# Out:
# WARNING:langchain.text_splitter:Created a chunk of size 1088, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1006, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1221, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1015, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2178, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1540, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1020, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2462, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1161, which is longer than the specified 1000
# ...

# %%
username = "ss" # replace with your username from app.activeloop.ai
db = DeepLake(dataset_path=f"hub://{username}/twitter-algorithm", embedding_function=embeddings)
db.add_documents(texts)
# Out:
# Your Deep Lake dataset has been successfully created!
# The dataset is private so make sure you are logged in!
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/ss/twitter-algorithm
# hub://ss/twitter-algorithm loaded successfully.
# Evaluating ingest: 100%|██████████| 26/26 [02:08<00:00
# |
# Dataset(path='hub://ss/twitter-algorithm', tensors=['embedding', 'ids', 'metadata', 'text'])
#
#   tensor     htype       shape       dtype  compression
#   -------   -------     -------     -------  -------
#  embedding  generic  (25747, 1536)  float32   None
#     ids      text     (25747, 1)      str     None
#  metadata    json     (25747, 1)      str     None
#    text      text     (25747, 1)      str     None
# ['f20f9290-ed44-11ed-ab07-0242ac1c000c',
#  'f20f956a-ed44-11ed-ab07-0242ac1c000c',
#  'f20f960a-ed44-11ed-ab07-0242ac1c000c',
#  'f20f9682-ed44-11ed-ab07-0242ac1c000c',
#  'f20f96f0-ed44-11ed-ab07-0242ac1c000c',
# ...

# %%
db = DeepLake(dataset_path="hub://davitbun/twitter-algorithm", read_only=True, embedding_function=embeddings)
# Out:
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/davitbun/twitter-algorithm
# \
# hub://davitbun/twitter-algorithm loaded successfully.
# Deep Lake Dataset in hub://davitbun/twitter-algorithm already exists, loading from the storage
# Dataset(path='hub://davitbun/twitter-algorithm', read_only=True, tensors=['embedding', 'ids', 'metadata', 'text'])
#
#   tensor     htype       shape       dtype  compression
#   -------   -------     -------     -------  -------
#  embedding  generic  (23152, 1536)  float32   None
#     ids      text     (23152, 1)      str     None
#  metadata    json     (23152, 1)      str     None
#    text      text     (23152, 1)      str     None

# %%
retriever = db.as_retriever()
retriever.search_kwargs['distance_metric'] = 'cos'
retriever.search_kwargs['fetch_k'] = 100
retriever.search_kwargs['maximal_marginal_relevance'] = True
retriever.search_kwargs['k'] = 10

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain

model = ChatOpenAI(model='gpt-3.5-turbo') # switch to 'gpt-4'
qa = ConversationalRetrievalChain.from_llm(model,retriever=retriever)

# %%
questions = [
    "What does favCountParams do?"
] 
chat_history = []

for question in questions:  
    result = qa({"question": question, "chat_history": chat_history})
    chat_history.append((question, result['answer']))
    print(f"-> **Question**: {question} \n")
    print(f"**Answer**: {result['answer']} \n")
# Out:
# -> **Question**: What does favCountParams do?
#
# **Answer**: It is not possible to determine what the `favCountParams` does without additional context. The given code only shows the declaration of a `ThriftLinearFeatureRankingParams` object with `favCountParams` as an optional parameter.
